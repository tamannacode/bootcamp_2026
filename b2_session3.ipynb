# %% [markdown]
# <a href="https://colab.research.google.com/github/tamannacode/bootcamp_2026/blob/main/b2_session3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#string
a="Tamanna"
print(a)
#integer
b=10
print(b)
#float
c=9.5
print(c)
#boolean
d=True
print(d)
# Out:
# Tamanna
# 10
# 9.5
# True

# %% [markdown]
# CREATE A LIST OF 5 SUBJECTS AND PRINT THE 1ST AND LAST ELEMENT

# %%
s=['maths','english','hindi','science','socialscience']
print(s[0],s[-1])
# Out:
# maths socialscience

# %% [markdown]
# WRITE A CODE FOR PASS OR FAIL, PASS BE 40 OR ABOVE RUN THIS CODE ON A LIST OF STUDENT OF 5 STUDENTS

# %%
marks= [35,78,40,22,60]
for i in range(len(marks)):
  if marks[i]>=40:
    print("Student",i+1,"-",marks[i],":Pass")
  else:
    print("Student",i+1,'-',marks[i],":Fail")
# Out:
# Student 1 - 35 :Fail
# Student 2 - 78 :Pass
# Student 3 - 40 :Pass
# Student 4 - 22 :Fail
# Student 5 - 60 :Pass

# %%
students = {
    "Aman": 75,
    "Riya": 38,
    "Rahul": 55,
    "Sneha": 29,
    "Vikram": 40
}
for name,marks in students.items():
  if marks<40:
    print(name,"has failed")
  else:
    print(name,"has passed")
# Out:
# Aman has passed
# Riya has failed
# Rahul has passed
# Sneha has failed
# Vikram has passed

# %% [markdown]
# CODE TO CHECK WHETHER NUMBER IS POSITIVE, NEGATIVE OR ZERO IN A GIVEN LIST OF NUMBER

# %%
# List of numbers
numbers = [10, -5, 0, 25, -8]

for num in numbers:
    if num > 0:
        print(num, "- Positive")
    elif num < 0:
        print(num, "- Negative")
    else:
        print(num, "- Zero")
# Out:
# 10 - Positive
# -5 - Negative
# 0 - Zero
# 25 - Positive
# -8 - Negative

# %% [markdown]
# **STUDENT NAME AS INPUT**

# %% [markdown]
# BASED ON THEIR MARKS YOU HAVE TO CONSIDER A PRINT STATEMENT FOR "PERFORMENCE" MARKS IS MORE THAN 75 THEN PERFORMANCE IS STRONG MARKS IS EQUAL TO OR GREATER THAN 40, PERFORMANCE SHOULD PRINT NEED TO IMPORVEMENT LESS 20 THEN PRINT FAIL ,REPEAT CLASS
#
# ATENDANCE 75- WARNING LOW ATTENDANCE STUDY_HOUR LESS THAN 4 PRINT SHOULD COME WARNING NEEDS MORE STUDY TIME

# %%
students = {
    "Tamanna": {"study_hours": 5, "attendance": 80, "marks": 85},
    "Riva": {"study_hours": 3, "attendance": 70, "marks": 60},
    "Aman": {"study_hours": 2, "attendance": 65, "marks": 15},
    "Rohit": {"study_hours": 6, "attendance": 90, "marks": 78},
    "Neha": {"study_hours": 4, "attendance": 72, "marks": 45}
}

name = input("Enter student name: ")

if name in students:
    s = students[name]

    print("Marks:", s["marks"])

    if s["marks"] > 75:
        print("Performance: Strong")
    elif s["marks"] >= 40:
        print("Performance: Needs Improvement")
    elif s["marks"] < 20:
        print("Performance: Fail, Repeat Class")

    if s["attendance"] < 75:
        print("Warning: Low Attendance")

    if s["study_hours"] < 4:
        print("Warning: Needs More Study Time")

else:
    print("Student not found")
# Out:
# Enter student name: Tamanna
# Marks: 85
# Performance: Strong

# %%
student_name="Tamanna"
student_age=17
attendance=89.9
is_present=True
print(student_name)
print(student_age)
print(attendance)
print(is_present)
# Out:
# Tamanna
# 17
# 89.9
# True

# %% [markdown]
# transactions = [ {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"}, {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"}, {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"}, {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"}, {"transaction_id": "TX105", "amount": 450, "method": "PayPal"} ] flagged_transaction = []

# %% [markdown]
# **WRITE A CODE BELOW TO FIND ANOMALOUS PATTERNS**

# %%
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]
flagged_transactions = []
for t in transactions:
    if t["amount"] > 5000 and t["method"] == "Gift Card":
        flagged_transactions.append(t["transaction_id"])
print(flagged_transactions)
# Out:
# ['TX102', 'TX104']
